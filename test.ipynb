# %%
# !ps -p $$
# !echo $SHELL
# Out:
#     PID TTY          TIME CMD
#  667007 pts/4    00:00:00 ps
# /bin/bash

# %%
from fastbook import *

# %%
urls = search_images_ddg('bird photos', max_images=1)
len(urls),urls[0]
# PixSpy can be used to view images
# Out:
# (1,
#  'https://images.pexels.com/photos/97533/pexels-photo-97533.jpeg?cs=srgb&dl=animal-avian-bird-97533.jpg&fm=jpg')

# %%
# Out:
# ('bird.jpg', <http.client.HTTPMessage at 0x7f04d544f070>)

# %%
dest = Path('bird.jpg')
#if not dest.exists(): download_url(urls[0], dest, show_progres=False) #original this fails
if not dest.exists(): download_url(urls[0], dest) #c4096: the function definition changed between the creation of the course video and now
# urlretrieve(urls[0], dest) #c4096: alternate method
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='450560' class='' max='447574' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.67% [450560/447574 00:00&lt;00:00]
#     </div>

# %%
im = Image.open(dest)
im.to_thumb(256,256)
# PixSpy is a website that shows RGB values as you move your cursor across an image and can be used for illustrative purposes
# Out:
# <PIL.Image.Image image mode=RGB size=256x192>

# %%
searches = 'forest','bird'
path = Path('bird_or_not')

if not path.exists():
    for o in searches:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_ddg(f'{o} photo')
        download_images(dest, urls=results[:200])
        resize_images(dest, max_size=400, dest=dest)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 for o in searches:
#       6     dest = (path/o)
# ----> 7     dest.mkdir(exist_ok=True)
#       8     results = search_images_ddg(f'{o} photo')
#       9     download_images(dest, urls=results[:200])
#
# File /usr/lib/python3.10/pathlib.py:1175, in Path.mkdir(self, mode, parents, exist_ok)
#    1171 """
#    1172 Create a new directory at this given path.
#    1173 """
#    1174 try:
# -> 1175     self._accessor.mkdir(self, mode)
#    1176 except FileNotFoundError:
#    1177     if not parents or self.parent == self:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bird_or_not/forest'
